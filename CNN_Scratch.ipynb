# %% [markdown]
# # CNN from scratch
#
# ## Import libraries and dataset

# %%
import numpy as np
import torch
import tensorboardX
from pa2_sample_code import get_datasets, show_image

train_dataset, eval_dataset = get_datasets()
show_image(train_dataset, 10)
show_image(eval_dataset, 10)
# Out:
# 0it [00:00, ?it/s]
# ...
#   4%|▎         | 20471808/561583919 [01:04<08:09, 1105286.55it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-049722f9118d> in <module>
#       4 from pa2_sample_code import get_datasets, show_image
#       5
# ----> 6 train_dataset, eval_dataset = get_datasets()
#       7 show_image(train_dataset, 10)
#       8 show_image(eval_dataset, 10)
#
# ~/Development/COMP4211_Assignment_2/pa2_sample_code.py in get_datasets(split, save)
#      20   transform = Compose([ToTensor()])
#      21
# ---> 22   dataset = ConcatDataset([EMNIST(root=download_folder, split=split, download=True, train=False, transform=transform),
#      23                            EMNIST(root=download_folder, split=split, download=True, train=True, transform=transform)])
#      24
#
# ...
